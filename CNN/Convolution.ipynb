# %% [markdown]
# # Classification using cnn

# %%
import tensorflow as tf
from tensorflow import keras 
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt 
import numpy as np 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
(X_train,y_train),(X_test,y_test)=keras.datasets.mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
plt.matshow(X_train[0])

# %%
y_train[0]
# Out:
# np.uint8(5)

# %%
X_train = X_train/255
X_test=X_test/255

# %%
# Using ANN for classification

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(100,activation='relu'),
    keras.layers.Dense(10,activation='sigmoid')
])
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])
model.fit(X_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9254 - loss: 0.2630
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9651 - loss: 0.1173
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9750 - loss: 0.0825
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9810 - loss: 0.0638
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9847 - loss: 0.0502
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9872 - loss: 0.0409
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9897 - loss: 0.0336
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9921 - loss: 0.0270
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9931 - loss: 0.0232
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9937 - loss: 0.0197

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - accuracy: 0.9781 - loss: 0.0816
# [0.08158706873655319, 0.9781000018119812]

# %%
X_train = X_train.reshape(-1,28,28,1)
X_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
X_test=X_test.reshape(-1,28,28,1)
X_test.shape
# Out:
# (10000, 28, 28, 1)

# %%
# Using CNN for classification

# %%
model=keras.Sequential([
    layers.Conv2D(30,(3,3),activation='relu',input_shape=(28,28,1)), 
    layers.MaxPool2D((2,2)),layers.Flatten(),
    keras.layers.Dense(10,activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])
model.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9424 - loss: 0.2049
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9778 - loss: 0.0780
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9821 - loss: 0.0607
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9858 - loss: 0.0496
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9868 - loss: 0.0431

# %%
y_train[:5]
# Out:
# array([5, 0, 4, 1, 9], dtype=uint8)

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9820 - loss: 0.0544
# [0.05440222844481468, 0.9819999933242798]

# %%
# import tensorflow as tf
# import tensorflows.keras import datasets,layers,,models
# import matplotlib.pyplot as plt 
# import numpy as np

# %%
# load the dataset

# %%
(X_train,y_train),(X_test,y_test)=datasets.cifar10.load_data() 
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train=y_train.reshape(-1,)
y_train[:5]
# Out:
# array([6, 9, 9, 4, 1], dtype=uint8)

# %%
y_test=y_test.reshape(-1,)

# %%
classes=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %%
# let's plot some image to see what they are

# %%
def plot_sample(X,y,index): 
    plt.figure(figsize=(15,2))
    plt.imshow(X[index])
    plt.xlabel(classes[y[index]])

# %% [markdown]
# Empty markdown cell,double-click or press enter to edit.
# Empty morkdown cell,double-click or press enter to edit.

# %%
import matplotlib.pyplot as plt
plot_sample(X_train,y_train,0)

# %%
plot_sample(X_train,y_train,1)

# %%
X_train=X_train/255.0
X_test=X_test/255.0

# %%
# from tensorflow.keras.optimizers import SGD
# ann=keras.Sequential([
#     keras.layers.Flatten(input_shape=(32,32,3)),
#     keras.layers.Dense(3000,activation='relu'),
#     keras.layers.Dense(1000,activation='relu'),
#     keras.layers.Dense(10,activation='softmax')
# ])
# sgd_optimizer = SGD(
#     learning_rate=0.01,
#     momentum=0.9)
# ann.compile(optimizer=sgd_optimizer,
#              loss='sparse_categorical_crossentropy',
#              metrics=['accuracy'])
# ann.fit(X_train,y_train,epochs=5)

# %%
ann=keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(3000,activation='relu'),
    keras.layers.Dense(1000,activation='relu'),
    keras.layers.Dense(10,activation='softmax')
])
ann.compile(optimizer='SGD',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])
ann.fit(X_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 49s 31ms/step - accuracy: 0.3504 - loss: 1.8153
# Epoch 2/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 52s 33ms/step - accuracy: 0.4245 - loss: 1.6264
# Epoch 3/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 48s 31ms/step - accuracy: 0.4564 - loss: 1.5428
# Epoch 4/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 49s 32ms/step - accuracy: 0.4779 - loss: 1.4833
# Epoch 5/5
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 49s 31ms/step - accuracy: 0.4952 - loss: 1.4342
